# %%
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Login_Data.csv')

# %%
df.head(10)
# Out:
#   Login Timestamp       User ID       IP Address Country    Region       City  \
# 0         43:30.8 -4.320000e+18      10.0.65.171      NO         -          -
# 1         43:43.5 -4.320000e+18     194.87.207.6      AU         -          -
# 2         43:55.9 -3.280000e+18    81.167.144.58      NO  Vestland  Urangsvag
# 3         43:56.2 -4.320000e+18    170.39.78.152      US         -          -
# 4         43:59.4 -4.620000e+18        10.0.0.47      US  Virginia    Ashburn
# 5         44:05.2 -4.320000e+18  209.236.123.126      US         -          -
# 6         44:07.9  7.250000e+18   80.202.228.214      NO         -          -
# 7         44:12.8 -3.240000e+18    170.39.78.177      US         -          -
# 8         44:17.5  8.080000e+18      10.0.61.212      NO         -          -
# 9         44:19.1 -3.070000e+18   92.221.109.162      NO  Rogaland    Sandnes
#
#           Browser Name and Version       Browser Category Device Type  \
# 0              Firefox 20.0.0.1618              Firefox        mobile
# 1          Chrome Mobile 46.0.2490         Chrome Mobile       mobile
# 2               Android 2.3.3.2672              Android        mobile
# 3  Chrome Mobile WebView 85.0.4183  Chrome Mobile WebView      mobile
# 4  Chrome Mobile WebView 85.0.4183  Chrome Mobile WebView      mobile
# 5  Chrome Mobile WebView 85.0.4183  Chrome Mobile WebView      mobile
# 6           Chrome 69.0.3497.17.19               Chrome       desktop
# 7     Chrome Mobile 81.0.4044.1931         Chrome Mobile       mobile
# 8               MiuiBrowser 12.6.5          MiuiBrowser        mobile
# 9           Chrome 69.0.3497.17.28               Chrome       desktop
#
#    Login Successful
# 0             False
# 1             False
# 2              True
# 3             False
# 4             False
# 5             False
# 6              True
# 7             False
# 8             False
# 9              True

# %%
df['Device Type'].value_counts()
# Out:
# Device Type
# mobile     765154
# desktop    248980
# tablet      32809
# bot           901
# unknown       673
# Name: count, dtype: int64

# %%
df['Device Type'] = df['Device Type'].fillna(value='unknown')

# %%
df['City'].value_counts()
df["City"] = df["City"].replace("-", "unknown") 
df['City'] = df['City'].fillna(value='unknown')

# %%
df['Region'].value_counts() 
df["Region"] = df["Region"].replace("-", "unknown")
df['Region'] = df['Region'].fillna(value='unknown')

# %%
top_user_id = df['User ID'].value_counts().idxmax()

# Remove all rows associated with the top user
df.drop(df[df['User ID'] == top_user_id].index, inplace=True)

# Verify the removal
unique_users = df['User ID'].nunique()
print("Number of unique users after removal:", unique_users)
# Out:
# Number of unique users after removal: 5307

# %%
df['Browser Category'].nunique()
# Out:
# 43

# %%
df["Browser Category"] = df["Browser Category"].replace("-", "unknown")
df['Browser Category'] = df['Browser Category'].fillna(value='unknown')

# %%
# Check the first few rows to inspect the timestamp format
print(df['Login Timestamp'].head())
# Out:
# 2    43:55.9
# 4    43:59.4
# 6    44:07.9
# 7    44:12.8
# 8    44:17.5
# Name: Login Timestamp, dtype: object

# %%
# Replace invalid time entries with NaT (Not a Time) or a default timestamp
df['Login Timestamp'] = pd.to_datetime(df['Login Timestamp'], errors='coerce')
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_30344\1059496503.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Login Timestamp'] = pd.to_datetime(df['Login Timestamp'], errors='coerce')

# %%
# Extract date and time components
df['Date'] = df['Login Timestamp'].dt.date
df['Time'] = df['Login Timestamp'].dt.time

# %%
# Check for NaT values in the 'Login Timestamp' column
print(df[df['Login Timestamp'].isna()])

# Optionally, drop or fill NaT values
df.dropna(subset=['Login Timestamp'], inplace=True)
# Out:
#         Login Timestamp       User ID       IP Address Country  \
# 2                   NaT -3.280000e+18    81.167.144.58      NO
# 4                   NaT -4.620000e+18        10.0.0.47      US
# 6                   NaT  7.250000e+18   80.202.228.214      NO
# 7                   NaT -3.240000e+18    170.39.78.177      US
# 8                   NaT  8.080000e+18      10.0.61.212      NO
# ...                 ...           ...              ...     ...
# 1048568             NaT  9.000000e+18    79.160.51.229      NO
# 1048570             NaT -1.290000e+18    78.91.142.173      NO
# 1048572             NaT  6.730000e+18  209.236.117.250      US
# 1048573             NaT -2.320000e+18      10.0.82.206      PL
# 1048574             NaT  4.360000e+18   37.191.209.129      NO
#
#                     Region       City         Browser Name and Version  \
# 2                 Vestland  Urangsvag               Android 2.3.3.2672
# 4                 Virginia    Ashburn  Chrome Mobile WebView 85.0.4183
# 6                  unknown    unknown           Chrome 69.0.3497.17.19
# 7                  unknown    unknown     Chrome Mobile 81.0.4044.1931
# 8                  unknown    unknown               MiuiBrowser 12.6.5
# ...                    ...        ...                              ...
# 1048568  Troms og Finnmark    Harstad              Firefox 20.0.0.1673
# 1048570            unknown    unknown                 Chrome 73.0.3654
# 1048572            unknown    unknown     Chrome Mobile 81.0.4044.1924
# 1048573            unknown    unknown          Chrome Mobile 81.0.4044
# 1048574        Oslo County       Oslo           Chrome 69.0.3497.17.19
#
#               Browser Category Device Type  Login Successful Date Time
# 2                    Android        mobile              True  NaT  NaT
# 4        Chrome Mobile WebView      mobile             False  NaT  NaT
# 6                     Chrome       desktop              True  NaT  NaT
# 7               Chrome Mobile       mobile             False  NaT  NaT
# 8                MiuiBrowser        mobile             False  NaT  NaT
# ...                        ...         ...               ...  ...  ...
# 1048568              Firefox        mobile              True  NaT  NaT
# 1048570               Chrome       desktop              True  NaT  NaT
# 1048572         Chrome Mobile       mobile             False  NaT  NaT
# 1048573         Chrome Mobile       mobile             False  NaT  NaT
# 1048574               Chrome       desktop             False  NaT  NaT
#
# [402351 rows x 12 columns]

# %%
df['Timestamp'] = pd.to_datetime(df['Login Timestamp'])

df['Year'] = df['Timestamp'].dt.year
df['Month'] = df['Timestamp'].dt.month
df['Day'] = df['Timestamp'].dt.day
df['Hour'] = df['Timestamp'].dt.hour
df['Minute'] = df['Timestamp'].dt.minute
df['Second'] = df['Timestamp'].dt.second

# %%
df[['Octet1', 'Octet2', 'Octet3', 'Octet4']] = df['IP Address'].str.split('.', expand=True).astype(int)

# %%
df = df.drop(['Login Timestamp', 'IP Address', 'Timestamp'], axis = 1)

# %%
df['NumSuccessfulLogins'] = df.groupby('User ID')['Login Successful'].transform('sum')

# Grouping the data by "User ID" and count the number of False values in "Login Successful"
false_counts = df[df['Login Successful'] == False].groupby('User ID').size().reset_index(name='NumUnsuccessfulLogins')

# Merging the false_counts DataFrame with the original data
df = df.merge(false_counts, on='User ID', how='left')

# Filling NaN values in the new column with 0
df['NumUnsuccessfulLogins'] = df['NumUnsuccessfulLogins'].fillna(0)

# Converting the values in the "False Count" column to integers
df['NumUnsuccessfulLogins'] = df['NumUnsuccessfulLogins'].astype(int)

# %%
df['NumSuccessfulLogins'] = df['NumSuccessfulLogins'].replace(0, 1)

# %%
df['LoginRatio'] = df['NumUnsuccessfulLogins'] / df['NumSuccessfulLogins']
df['LoginRatio'].replace(np.inf, 0, inplace=True)
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_30344\436070362.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoginRatio'].replace(np.inf, 0, inplace=True)

# %%
df = df.drop(['NumSuccessfulLogins', 'NumUnsuccessfulLogins'], axis = 1)

# %%
# Calculating the total number of different device types used by each user
device_counts = df.groupby('User ID')['Device Type'].transform('nunique')

# Adding the column to the DataFrame
df['Total Devices Per User'] = device_counts

# %%
# Calculating the total number of different countries visited by each user
country_counts = df.groupby('User ID')['Country'].transform('nunique')

# Adding the column to the DataFrame
df['Total Countries Per User'] = country_counts

# %%
# Calculating the total number of different browser categories used by each user
browser_counts = df.groupby('User ID')['Browser Category'].transform('nunique')

# Add the 'Total Browser Categories' column to the DataFrame
df['Total Browser Categories Per User'] = browser_counts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266746 entries, 0 to 266745
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   User ID                            266746 non-null  float64
#  1   Country                            266746 non-null  object
#  2   Region                             266746 non-null  object
#  3   City                               266746 non-null  object
#  4   Browser Name and Version           266746 non-null  object
#  5   Browser Category                   266746 non-null  object
#  6   Device Type                        266746 non-null  object
#  7   Login Successful                   266746 non-null  bool
#  8   Date                               266746 non-null  object
#  9   Time                               266746 non-null  object
#  10  Year                               266746 non-null  int32
#  11  Month                              266746 non-null  int32
#  12  Day                                266746 non-null  int32
#  13  Hour                               266746 non-null  int32
#  14  Minute                             266746 non-null  int32
#  15  Second                             266746 non-null  int32
#  16  Octet1                             266746 non-null  int32
#  17  Octet2                             266746 non-null  int32
#  18  Octet3                             266746 non-null  int32
#  19  Octet4                             266746 non-null  int32
#  20  LoginRatio                         266746 non-null  float64
#  21  Total Devices Per User             266746 non-null  int64
#  22  Total Countries Per User           266746 non-null  int64
#  23  Total Browser Categories Per User  266746 non-null  int64
# dtypes: bool(1), float64(2), int32(10), int64(3), object(8)
# memory usage: 36.9+ MB

# %%
df.head()
# Out:
#         User ID Country    Region     City  \
# 0  9.310000e+17      US     Texas   Dallas
# 1  1.900000e+18      NO  Rogaland     Sola
# 2 -5.720000e+18      NO   unknown  unknown
# 3 -8.630000e+18      NO   unknown  unknown
# 4 -5.370000e+18      BR   unknown  unknown
#
#                Browser Name and Version       Browser Category Device Type  \
# 0                   Firefox 20.0.0.1618              Firefox        mobile
# 1                   Firefox 20.0.0.1618              Firefox        mobile
# 2  Chrome Mobile WebView 87.0.4280.2259  Chrome Mobile WebView      tablet
# 3                   Chrome 72.0.3626.55               Chrome       desktop
# 4                           Android 2.0              Android        mobile
#
#    Login Successful        Date      Time  ...  Minute  Second  Octet1  \
# 0              True  2024-12-12  00:01:12  ...       1      12      45
# 1             False  2024-12-12  00:06:12  ...       6      12     152
# 2              True  2024-12-12  00:07:24  ...       7      24      37
# 3              True  2024-12-12  00:07:30  ...       7      30     139
# 4              True  2024-12-12  00:08:24  ...       8      24      79
#
#    Octet2  Octet3  Octet4  LoginRatio  Total Devices Per User  \
# 0     144     247      99    0.500000                       3
# 1      93     203     219    0.225490                       3
# 2      97      53      70    0.344538                       3
# 3     164     186      51    0.333333                       3
# 4     161      38       5    0.405063                       3
#
#    Total Countries Per User  Total Browser Categories Per User
# 0                         4                                  6
# 1                         9                                 10
# 2                        13                                 11
# 3                         8                                  8
# 4                        11                                  9
#
# [5 rows x 24 columns]

# %%
# Select the categorical columns to encode
categorical_columns = ['Country', 'Region', 'City', 'Device Type', 'Browser Category']

# Encode categorical columns using LabelEncoder
label_encoder = LabelEncoder()
for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

# %%
# Convert the 'Login Successful' column to int
df['Login Successful'] = df['Login Successful'].astype(int)

# Convert the 'LoginRatio' column to int or any other desired data type
df['LoginRatio'] = df['LoginRatio'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266746 entries, 0 to 266745
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   User ID                            266746 non-null  float64
#  1   Country                            266746 non-null  int32
#  2   Region                             266746 non-null  int32
#  3   City                               266746 non-null  int32
#  4   Browser Name and Version           266746 non-null  object
#  5   Browser Category                   266746 non-null  int32
#  6   Device Type                        266746 non-null  int32
#  7   Login Successful                   266746 non-null  int32
#  8   Date                               266746 non-null  object
#  9   Time                               266746 non-null  object
#  10  Year                               266746 non-null  int32
#  11  Month                              266746 non-null  int32
#  12  Day                                266746 non-null  int32
#  13  Hour                               266746 non-null  int32
#  14  Minute                             266746 non-null  int32
#  15  Second                             266746 non-null  int32
#  16  Octet1                             266746 non-null  int32
#  17  Octet2                             266746 non-null  int32
#  18  Octet3                             266746 non-null  int32
#  19  Octet4                             266746 non-null  int32
#  20  LoginRatio                         266746 non-null  int32
#  21  Total Devices Per User             266746 non-null  int64
#  22  Total Countries Per User           266746 non-null  int64
#  23  Total Browser Categories Per User  266746 non-null  int64
# dtypes: float64(1), int32(17), int64(3), object(3)
# memory usage: 31.5+ MB

# %%
df.head()
# Out:
#         User ID  Country  Region  City              Browser Name and Version  \
# 0  9.310000e+17      150     633  1099                   Firefox 20.0.0.1618
# 1  1.900000e+18      110     547  4173                   Firefox 20.0.0.1618
# 2 -5.720000e+18      110     727  5009  Chrome Mobile WebView 87.0.4280.2259
# 3 -8.630000e+18      110     727  5009                   Chrome 72.0.3626.55
# 4 -5.370000e+18       22     727  5009                           Android 2.0
#
#    Browser Category  Device Type  Login Successful        Date      Time  ...  \
# 0                12            1                 1  2024-12-12  00:01:12  ...
# 1                12            1                 0  2024-12-12  00:06:12  ...
# 2                 7            2                 1  2024-12-12  00:07:24  ...
# 3                 5            0                 1  2024-12-12  00:07:30  ...
# 4                 3            1                 1  2024-12-12  00:08:24  ...
#
#    Minute  Second  Octet1  Octet2  Octet3  Octet4  LoginRatio  \
# 0       1      12      45     144     247      99           0
# 1       6      12     152      93     203     219           0
# 2       7      24      37      97      53      70           0
# 3       7      30     139     164     186      51           0
# 4       8      24      79     161      38       5           0
#
#    Total Devices Per User  Total Countries Per User  \
# 0                       3                         4
# 1                       3                         9
# 2                       3                        13
# 3                       3                         8
# 4                       3                        11
#
#    Total Browser Categories Per User
# 0                                  6
# 1                                 10
# 2                                 11
# 3                                  8
# 4                                  9
#
# [5 rows x 24 columns]

# %%
selected_columns = ['Octet1', 'Octet2', 'Octet3', 'LoginRatio', 'Total Devices Per User', 'Total Countries Per User', 'Total Browser Categories Per User','Country', 'City', 'Region','Device Type', 'Login Successful','Browser Category']

# %%
# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[selected_columns])

# %%
# Perform PCA
pca = PCA()
pca.fit(X_scaled)
# Out:
# PCA()

# %%
# Access the explained variance ratios or principal component loadings
explained_variance_ratio = pca.explained_variance_ratio_
principal_component_loadings = pca.components_

# %%
# Print the explained variance ratios or principal component loadings
for feature, variance_ratio, loadings in zip(selected_columns, explained_variance_ratio, principal_component_loadings):
    print(f"{feature}: Explained Variance Ratio = {variance_ratio}, Loadings = {loadings}")
# Out:
# Octet1: Explained Variance Ratio = 0.17175074772245733, Loadings = [-0.00673444 -0.00280296 -0.00208912 -0.27971109  0.54258831  0.56047206
#   0.55886223 -0.01909162 -0.00710235 -0.00918595  0.00409159  0.01612451
#   0.00837148]
# Octet2: Explained Variance Ratio = 0.13259485881386793, Loadings = [ 0.41960912  0.11456934  0.1166142   0.02017348  0.01293902  0.00585173
#   0.02629939  0.32085337  0.52390892  0.52960176  0.28472149 -0.20937538
#   0.11442485]
# Octet3: Explained Variance Ratio = 0.09815397604083612, Loadings = [-0.23387296 -0.42313787 -0.30005188  0.08521686 -0.00205048  0.00661065
#   0.02565697  0.03563104 -0.08171056 -0.11260129  0.54819437 -0.25475048
#   0.53124235]
# LoginRatio: Explained Variance Ratio = 0.09507168651607127, Loadings = [ 1.83308168e-01  6.13860937e-01  4.10851416e-01  1.70021292e-03
#  -6.06875548e-04 -1.15494915e-02  3.59769522e-03 -3.50284452e-03
#  -3.30028534e-01 -2.86319338e-01  2.89502947e-01 -2.09332148e-02
#   3.81397907e-01]
# Total Devices Per User: Explained Variance Ratio = 0.07822144782095079, Loadings = [ 0.00493528 -0.06613642  0.02675625 -0.33451297 -0.05528452 -0.07577167
#  -0.07137836 -0.36554292  0.21977246  0.18267154  0.08301819  0.71152807
#   0.37501938]
# Total Countries Per User: Explained Variance Ratio = 0.07439932896305229, Loadings = [-0.52839754 -0.19458861  0.75118503  0.12573964  0.00644819  0.03605075
#   0.01966287 -0.15534066  0.17264546  0.15032904 -0.00520825 -0.15601308
#   0.01452054]
# Total Browser Categories Per User: Explained Variance Ratio = 0.07142481673944355, Loadings = [-0.30539458 -0.03498728  0.09967977 -0.47160704 -0.03236284 -0.11817784
#  -0.07112883  0.76053966 -0.14912466  0.00199765  0.06118929  0.21218203
#  -0.06049833]
# Country: Explained Variance Ratio = 0.06580468198715762, Loadings = [-0.11277981  0.0493269  -0.04202326  0.74377539  0.07782933  0.14243684
#   0.14906686  0.32989357 -0.04290036  0.0894339  -0.0521771   0.49558675
#   0.11964901]
# City: Explained Variance Ratio = 0.055753955789556574, Loadings = [ 0.25055464 -0.26665677  0.20433371  0.074982    0.01939203  0.03836819
#  -0.02715764 -0.04828079  0.02159836 -0.28243835  0.60357833  0.2632094
#  -0.54772378]
# Region: Explained Variance Ratio = 0.04737122615331095, Loadings = [-0.45140666  0.46415472 -0.28697454  0.0029231   0.06712344 -0.01745814
#  -0.05020122 -0.20660443 -0.12628591  0.42644763  0.39285002 -0.00215847
#  -0.31027744]
# Device Type: Explained Variance Ratio = 0.04279321706612011, Loadings = [-2.87482924e-01  3.10756690e-01 -1.61818445e-01  9.22036336e-03
#   9.11038868e-03 -4.92966410e-03  2.15132506e-04  6.15743333e-02
#   7.00843689e-01 -5.46523479e-01  2.52619390e-02 -5.30747177e-04
#  -1.03267487e-02]
# Login Successful: Explained Variance Ratio = 0.036809169553839186, Loadings = [ 0.03408141 -0.04354894  0.02252237  0.067865    0.8286769  -0.33751817
#  -0.43223183  0.00316926  0.00959038 -0.02160608 -0.04018021 -0.00386391
#   0.04671763]
# Browser Category: Explained Variance Ratio = 0.029850886833336417, Loadings = [-4.16700268e-03  9.35034241e-03 -8.41257978e-03 -2.10711451e-02
#  -5.96087704e-02  7.27079608e-01 -6.80783589e-01  3.98275426e-02
#   2.99452116e-04  5.09045119e-03 -1.76529485e-02 -5.21218695e-03
#   4.20137668e-02]

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
 #Calculate the cumulative explained variance ratio
cumulative_var_ratio = np.cumsum(pca.explained_variance_ratio_)

plt.plot(range(1, len(cumulative_var_ratio) + 1), cumulative_var_ratio, marker='o', linestyle='-', color='b')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Cumulative Explained Variance Ratio vs. Number of Principal Components')
plt.grid(True)
plt.show()

# %%
#Octet1, Octet2, Octet3, LoginRatio, Total Devices Per User, Total Countries Per User, Total Browser Categories Per User, and Country appear to be relatively important features

# %%
# Import MiniBatchKMeans
from sklearn.cluster import MiniBatchKMeans

# Initialize the list for storing the WCSS values
wcss = []  
max_clusters = 10  

# Loop over different cluster sizes
for k in range(1, max_clusters + 1):
    # Initialize MiniBatchKMeans for k clusters
    kmeans = MiniBatchKMeans(n_clusters=k, random_state=0)
    
    # Fit the model to your scaled data
    kmeans.fit(X_scaled)
    
    # Append the inertia (WCSS) to the list
    wcss.append(kmeans.inertia_)

# %%
# Plot the elbow curve
plt.plot(range(1, max_clusters + 1), wcss, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
# Perform k-means clustering
k = 9  # Number of clusters
kmeans = KMeans(n_clusters=k, random_state=0)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=9, random_state=0)

# %%
# Get the cluster labels
cluster_labels = kmeans.labels_

# %%
# Add the cluster labels to the original dataset
df['Cluster'] = cluster_labels

# %%
# Analyze 
cluster_counts = df['Cluster'].value_counts()
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)

# %%
# Printing the cluster information
for cluster, count in cluster_counts.items():
    print(f"Cluster {cluster}: Count = {count}")
# Out:
# Cluster 1: Count = 47715
# Cluster 4: Count = 43371
# Cluster 8: Count = 39556
# Cluster 3: Count = 36286
# Cluster 0: Count = 29878
# Cluster 5: Count = 24661
# Cluster 2: Count = 22830
# Cluster 7: Count = 20339
# Cluster 6: Count = 2110

# %%
# Printing the cluster centers (average values for each feature)
for cluster, center in enumerate(cluster_centers):
    print(f"Cluster {cluster} Center:")
    for feature, value in zip(selected_columns, center):
        print(f"{feature}: {value}")
# Out:
# Cluster 0 Center:
# Octet1: 63.82760924762779
# Octet2: 166.9727382066024
# Octet3: 193.11706534812194
# LoginRatio: -8.673617379884035e-18
# Total Devices Per User: 3.0102231725243915
# Total Countries Per User: 11.139583054924492
# Total Browser Categories Per User: 10.08830014699987
# Country: 130.23914205532523
# City: 4673.603267406142
# Region: 672.7984097287176
# Device Type: 1.0329747427502318
# Login Successful: 0.6405853267406115
# Browser Category: 6.8661967125484455
# Cluster 1 Center:
# Octet1: 99.99687958115184
# Octet2: 170.87972774869098
# Octet3: 122.2989947643979
# LoginRatio: 4.111294638065033e-16
# Total Devices Per User: 3.016900523560214
# Total Countries Per User: 11.13805235602094
# Total Browser Categories Per User: 10.064628272251312
# Country: 109.88531937172775
# City: 3268.9521047120443
# Region: 569.0934031413619
# Device Type: 8.992806499463768e-15
# Login Successful: 0.8578638743455467
# Browser Category: 5.1973193717276525
# Cluster 2 Center:
# Octet1: 96.75194918966272
# Octet2: 126.32220762155058
# Octet3: 119.01568112133158
# LoginRatio: -3.0704605524789486e-16
# Total Devices Per User: 2.1024091108191185
# Total Countries Per User: 3.369776609724049
# Total Browser Categories Per User: 4.835742444152411
# Country: 110.79929916776173
# City: 3688.409417433202
# Region: 594.4413929040735
# Device Type: 0.7289531318440647
# Login Successful: 0.7793254489706526
# Browser Category: 8.126149802890927
# Cluster 3 Center:
# Octet1: 12.04686164787502
# Octet2: 4.634065661439024
# Octet3: 83.06756346996713
# LoginRatio: 1.9081958235744878e-16
# Total Devices Per User: 3.01058521928495
# Total Countries Per User: 11.194089919232567
# Total Browser Categories Per User: 10.02263141935662
# Country: 103.2759324089643
# City: 3309.865369242219
# Region: 529.2685999393559
# Device Type: 0.6421975356286377
# Login Successful: 0.7879096948479742
# Browser Category: 6.225073738181218
# Cluster 4 Center:
# Octet1: 174.2284519601739
# Octet2: 100.98080255041934
# Octet3: 96.84270104188325
# LoginRatio: 3.365363543395006e-16
# Total Devices Per User: 3.0107422551805434
# Total Countries Per User: 11.130223854736986
# Total Browser Categories Per User: 10.104257629311345
# Country: 136.56499641924765
# City: 4819.11305934811
# Region: 683.40455564026
# Device Type: 1.0092868528657422
# Login Successful: 0.6340471735162964
# Browser Category: 7.144084829163515
# Cluster 5 Center:
# Octet1: 89.6811711748246
# Octet2: 136.3887830001217
# Octet3: 116.31339470375927
# LoginRatio: 8.673617379884035e-18
# Total Devices Per User: 3.0126120280627786
# Total Countries Per User: 10.981913297376208
# Total Browser Categories Per User: 10.116590291577115
# Country: 108.26262216634908
# City: 3485.4543979885643
# Region: 589.2855346932155
# Device Type: 1.0657772010219344
# Login Successful: 0.7559106208686482
# Browser Category: 27.728942779512252
# Cluster 6 Center:
# Octet1: 96.81990521327015
# Octet2: 119.57582938388624
# Octet3: 116.41706161137441
# LoginRatio: 1.2843601895734618
# Total Devices Per User: 1.8763033175355437
# Total Countries Per User: 2.766824644549768
# Total Browser Categories Per User: 3.80473933649289
# Country: 113.3867298578199
# City: 3726.3909952606637
# Region: 610.5222748815165
# Device Type: 0.8184834123222751
# Login Successful: 0.3943127962085305
# Browser Category: 8.833649289099526
# Cluster 7 Center:
# Octet1: 126.85806261365299
# Octet2: 111.92873642305996
# Octet3: 128.64201110728854
# LoginRatio: -2.445960101127298e-16
# Total Devices Per User: 3.0140069789158117
# Total Countries Per User: 11.378827345554624
# Total Browser Categories Per User: 10.021379073082025
# Country: 36.02988155501987
# City: 4491.74571189857
# Region: 658.9249029340945
# Device Type: 0.7833095788076874
# Login Successful: 0.7457610458544257
# Browser Category: 7.082174276306078
# Cluster 8 Center:
# Octet1: 93.0498811751024
# Octet2: 173.12876068159952
# Octet3: 110.41998280831267
# LoginRatio: 2.636779683484747e-16
# Total Devices Per User: 3.015093290185573
# Total Countries Per User: 11.185215148910348
# Total Browser Categories Per User: 10.083986448905298
# Country: 111.45229306770496
# City: 2172.542144915801
# Region: 502.32224300955704
# Device Type: 1.0867168933609581
# Login Successful: 0.7691763159225357
# Browser Category: 6.411639783587008

# %%
data_selected = df[selected_columns]

# %%
tsne = TSNE(n_components=2, random_state=42)

# %%
data_tsne = tsne.fit_transform(data_selected)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Assuming data_tsne contains the t-SNE-transformed data and X_scaled is your original data
# Perform clustering (e.g., with KMeans)
kmeans = KMeans(n_clusters=3, random_state=0)  # Set the number of clusters
kmeans.fit(X_scaled)  # Fit to the scaled data

# Get the labels from the clustering result
labels = kmeans.labels_

# Plot the t-SNE visualization
plt.scatter(data_tsne[:, 0], data_tsne[:, 1], c=labels)
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization')
plt.show()
